# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-Martinez24/cuenca-empleados/blob/main/cuenca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preguntas
#
#
# 1.   ¿Cuantas personas trabajan en la cuenca?
# 2.  ¿Cuantas pertencen al ORGANISMO DE CUENCA LERMA SANTIAGO PACIFIC?
#
# Nota: la posible respuesta de la segunda es 284 segun la revisión rapida

# %%
# !pip install ghostscript
# !pip install camelot-py[cv]
# !pip install excalibur-py
# !apt install ghostscript python3-tk
from ctypes.util import find_library
print(find_library("gs")) #will display libgs.so.9 if installed; will print None if not
# !excalibur initdb

# se importa camelot
import camelot
# Out:
# Requirement already satisfied: ghostscript in /usr/local/lib/python3.7/dist-packages (0.7)
# Requirement already satisfied: setuptools>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from ghostscript) (57.2.0)
# Requirement already satisfied: camelot-py[cv] in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (0.8.9)
# Requirement already satisfied: openpyxl>=2.5.8 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (2.5.9)
# Requirement already satisfied: PyPDF2>=1.26.0 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (1.26.0)
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (3.0.4)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (1.19.5)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (1.1.5)
# Requirement already satisfied: pdfminer.six>=20200726 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (20201018)
# Requirement already satisfied: click>=6.7 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (7.1.2)
# Requirement already satisfied: opencv-python>=3.4.2.17 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (4.1.2.30)
# Requirement already satisfied: ghostscript>=0.7 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (0.7)
# Requirement already satisfied: pdftopng>=0.2.3 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]) (0.2.3)
# Requirement already satisfied: setuptools>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from ghostscript>=0.7->camelot-py[cv]) (57.2.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.5.8->camelot-py[cv]) (1.1.0)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.5.8->camelot-py[cv]) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->camelot-py[cv]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->camelot-py[cv]) (2.8.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from pdfminer.six>=20200726->camelot-py[cv]) (2.4.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.7/dist-packages (from pdfminer.six>=20200726->camelot-py[cv]) (3.4.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.4->camelot-py[cv]) (1.15.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->pdfminer.six>=20200726->camelot-py[cv]) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->pdfminer.six>=20200726->camelot-py[cv]) (2.20)
# Requirement already satisfied: excalibur-py in /usr/local/lib/python3.7/dist-packages (0.4.3)
# Requirement already satisfied: camelot-py[cv]>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from excalibur-py) (0.10.1)
# Requirement already satisfied: celery>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from excalibur-py) (5.1.2)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.7/dist-packages (from excalibur-py) (7.1.2)
# Requirement already satisfied: SQLAlchemy>=1.2.12 in /usr/local/lib/python3.7/dist-packages (from excalibur-py) (1.4.22)
# Requirement already satisfied: configparser<3.6.0,>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from excalibur-py) (3.5.3)
# Requirement already satisfied: Flask>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from excalibur-py) (1.1.4)
# Requirement already satisfied: Werkzeug<1.0.0 in /usr/local/lib/python3.7/dist-packages (from excalibur-py) (0.16.1)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (0.8.9)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (1.1.5)
# Requirement already satisfied: openpyxl>=2.5.8 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (2.5.9)
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (3.0.4)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (1.19.5)
# Requirement already satisfied: PyPDF2>=1.26.0 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (1.26.0)
# Requirement already satisfied: pdfminer.six>=20200726 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (20201018)
# Requirement already satisfied: pdftopng>=0.2.3 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (0.2.3)
# Requirement already satisfied: opencv-python>=3.4.2.17 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (4.1.2.30)
# Requirement already satisfied: ghostscript>=0.7 in /usr/local/lib/python3.7/dist-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (0.7)
# Requirement already satisfied: click-repl>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from celery>=4.1.1->excalibur-py) (0.2.0)
# Requirement already satisfied: vine<6.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from celery>=4.1.1->excalibur-py) (5.0.0)
# Requirement already satisfied: pytz>dev in /usr/local/lib/python3.7/dist-packages (from celery>=4.1.1->excalibur-py) (2018.9)
# Requirement already satisfied: click-didyoumean>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from celery>=4.1.1->excalibur-py) (0.0.3)
# Requirement already satisfied: kombu<6.0,>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from celery>=4.1.1->excalibur-py) (5.1.0)
# Requirement already satisfied: click-plugins>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from celery>=4.1.1->excalibur-py) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from celery>=4.1.1->excalibur-py) (57.2.0)
# Requirement already satisfied: billiard<4.0,>=3.6.4.0 in /usr/local/lib/python3.7/dist-packages (from celery>=4.1.1->excalibur-py) (3.6.4.0)
# Requirement already satisfied: prompt-toolkit in /usr/local/lib/python3.7/dist-packages (from click-repl>=0.1.6->celery>=4.1.1->excalibur-py) (1.0.18)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from click-repl>=0.1.6->celery>=4.1.1->excalibur-py) (1.15.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.2->excalibur-py) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.2->excalibur-py) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=1.0.2->excalibur-py) (2.0.1)
# Requirement already satisfied: amqp<6.0.0,>=5.0.6 in /usr/local/lib/python3.7/dist-packages (from kombu<6.0,>=5.1.0->celery>=4.1.1->excalibur-py) (5.0.6)
# Requirement already satisfied: importlib-metadata>=0.18 in /usr/local/lib/python3.7/dist-packages (from kombu<6.0,>=5.1.0->celery>=4.1.1->excalibur-py) (4.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from kombu<6.0,>=5.1.0->celery>=4.1.1->excalibur-py) (1.5.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.18->kombu<6.0,>=5.1.0->celery>=4.1.1->excalibur-py) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.18->kombu<6.0,>=5.1.0->celery>=4.1.1->excalibur-py) (3.7.4.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.5.8->camelot-py[cv]>=0.7.1->excalibur-py) (1.1.0)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.5.8->camelot-py[cv]>=0.7.1->excalibur-py) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->camelot-py[cv]>=0.7.1->excalibur-py) (2.8.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from pdfminer.six>=20200726->camelot-py[cv]>=0.7.1->excalibur-py) (2.4.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.7/dist-packages (from pdfminer.six>=20200726->camelot-py[cv]>=0.7.1->excalibur-py) (3.4.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=1.2.12->excalibur-py) (1.1.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->pdfminer.six>=20200726->camelot-py[cv]>=0.7.1->excalibur-py) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->pdfminer.six>=20200726->camelot-py[cv]>=0.7.1->excalibur-py) (2.20)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit->click-repl>=0.1.6->celery>=4.1.1->excalibur-py) (0.2.5)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ghostscript is already the newest version (9.26~dfsg+0-0ubuntu0.18.04.14).
# python3-tk is already the newest version (3.6.9-1~18.04).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# libgs.so.9
# Traceback (most recent call last):
#   File "/usr/local/bin/excalibur", line 5, in <module>
#     from excalibur.cli import cli
#   File "/usr/local/lib/python3.7/dist-packages/excalibur/cli.py", line 10, in <module>
#     from .tasks import split, extract
#   File "/usr/local/lib/python3.7/dist-packages/excalibur/tasks.py", line 13, in <module>
#     from camelot.ext.ghostscript import Ghostscript
# ModuleNotFoundError: No module named 'camelot.ext'

# %%
pdfCuencua = '/content/drive/MyDrive/proyectos/cuenca/Plantilla del personal.pdf'

# %%
tables = camelot.read_pdf(pdfCuencua, flavor='stream', pages='all')

# %%
# tiene 279 n pero el pdf tiene 274
tabla_final = tables[-1].df
tabla_final.drop(range(0,2),axis=0).reset_index(drop=True)

# tabla_final.rename(columns=tabla_final[1])
# Out:
#           0           1  ...    4          5
# 0    ZEPEDA   HERNANDEZ  ...    7       BASE
# 1    ZEPEDA       LOPEZ  ...  M42  CONFIANZA
# 2    ZEPEDA     MENDOZA  ...  O23  CONFIANZA
# 3    ZEPEDA     SALAZAR  ...    6  CONFIANZA
# 4   ZERMEÑO      MENDEZ  ...    6       BASE
# 5    ZETINA      GARCIA  ...    7       BASE
# 6    ZETINA       PEREZ  ...    6       BASE
# 7    ZETINA     ROBLEDA  ...  N11  CONFIANZA
# 8    ZETINA      TORRES  ...    7       BASE
# 9    ZETINA      TORRES  ...    7       BASE
# 10   ZUMAYA   HERNANDEZ  ...    6       BASE
# 11   ZUMAYA        LEON  ...    6       BASE
# 12   ZUÑIGA      ALANIZ  ...    6       BASE
# 13   ZUÑIGA      ARENAS  ...    7       BASE
# 14   ZUÑIGA      ARVIZU  ...    6       BASE
# 15   ZUÑIGA   CASTAÑEDA  ...    6       BASE
# 16   ZUÑIGA    DE LEIJA  ...    6       BASE
# 17   ZUÑIGA       FRIAS  ...    7       BASE
# 18   ZUÑIGA       GOMEZ  ...    6       BASE
# 19   ZUÑIGA       GOMEZ  ...    6       BASE
# 20   ZUÑIGA    GONZALEZ  ...  O11  CONFIANZA
# 21   ZUÑIGA   HERNANDEZ  ...    6  CONFIANZA
# 22   ZUÑIGA     NAVARRO  ...    6       BASE
# 23   ZUÑIGA        NULL  ...    7       BASE
# 24   ZUÑIGA     PAREDES  ...    6       BASE
# 25   ZUÑIGA        PIÑA  ...    8       BASE
# 26   ZUÑIGA     RAMIREZ  ...    6       BASE
# 27   ZUÑIGA   RODRIGUEZ  ...    6  CONFIANZA
# 28   ZUÑIGA     SALAZAR  ...    6  CONFIANZA
# 29   ZUÑIGA     TARANGO  ...    7       BASE
# 30   ZUÑIGA     TARANGO  ...    7       BASE
# 31   ZUÑIGA      TELLEZ  ...    7       BASE
# 32   ZUÑIGA  VALDERRAMA  ...    7  CONFIANZA
# 33   ZUÑIGA       VELOZ  ...    7       BASE
# 34   ZURITA     ESTRADA  ...    6       BASE
# 35   ZURITA     ESTRADA  ...    7       BASE
# 36   ZURITA    MARTINEZ  ...    7       BASE
# 37   ZURITA     MENDOZA  ...    7       BASE
# 38   ZURITA       ROGEL  ...    8       BASE
# 39                LOPEZ  ...    7       BASE
#
# [40 rows x 6 columns]

# %%
def limpiar_lista_dataframe(lista):
  '''
  Recibe la lista con DF y devuelve la misma lista con datos limpios
  '''
  lista_limpia = []
  for df in lista:
    lista_limpia.append(limpiar_df(df))
  return lista_limpia

# %%
def limpiar_df(df, espacios=range(0,2), cabecera=1):
  '''
  Devuelve el DF limpio
  '''
  nuevo_df = df.drop(espacios,axis=0).reset_index(drop=True)
  return nuevo_df

# %%
nueva_lista = limpiar_lista_dataframe(tables)
nueva_lista[-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-473ce824c4e3> in <module>()
# ----> 1 nueva_lista = limpiar_lista_dataframe(tables)
#       2 nueva_lista[-1]
#
# <ipython-input-77-d043dfc1b5be> in limpiar_lista_dataframe(lista)
#       5   lista_limpia = []
#       6   for df in lista:
# ----> 7     lista_limpia.append(limpiar_df(df))
#       8   return lista_limpia
#
# <ipython-input-75-f60864c3820b> in limpiar_df(df, espacios, cabecera)
#       3   Devuelve el DF limpio
#       4   '''
# ----> 5   nuevo_df = df.drop(espacios,axis=0).reset_index(drop=True)
#       6   return nuevo_df
#
# AttributeError: 'Table' object has no attribute 'drop'

# %% [markdown]
# Primera pregunta

# %% [markdown]
# Segunda

# %% [markdown]
# MEtodo alterntivo de descarga
